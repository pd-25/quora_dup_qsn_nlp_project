# %% [markdown]
# <a href="https://colab.research.google.com/github/pd-25/quora_dup_qsn_nlp_project/blob/main/quora_dup_qsn_nlp_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#/content/train.csv
import pandas as pd

df = pd.read_csv('train.csv')
df.head(10)
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
# 5   5    11    12  Astrology: I am a Capricorn Sun Cap moon and c...
# 6   6    13    14                                Should I buy tiago?
# 7   7    15    16                     How can I be a good geologist?
# 8   8    17    18                    When do you use シ instead of し?
# 9   9    19    20  Motorola (company): Can I hack my Charter Moto...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# ...

# %% [markdown]
# We get the dataset now we will explore the dataset

# %%
#check the shape
df.shape
# Out:
# (404290, 6)

# %%
df.sample(10)
# Out:
#             id    qid1    qid2  \
# 190857  190857  290049  290050
# 91879    91879  153910   38191
# 129409  129409   21401   97973
# 186089  186089   16573  211682
# 215809  215809   66575  321796
# 386566  386566    5297   32868
# 9724      9724   18884   18885
# 58579    58579   48023  102748
# 347495  347495  193070  156299
# 336163  336163   25050   10488
#
#                                                 question1  \
# 190857  Is the digital locker launched by the governme...
# 91879   What is the weirdest present you got for your ...
# 129409               How do you exactly start a business?
# 186089  What is the main reason for discontinuing 500 ...
# 215809   How can I pick out the Air Marshal on my flight?
# 386566                     How do you control your anger?
# 9724                     How can I get rid from dandruff?
# 58579   If [math]1\circ4=5[/math] and [math]2\circ5=12...
# 347495                 How do I clear both group of ipcc?
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            404290 non-null  int64
#  1   qid1          404290 non-null  int64
#  2   qid2          404290 non-null  int64
#  3   question1     404289 non-null  object
#  4   question2     404288 non-null  object
#  5   is_duplicate  404290 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %%
#check which colm has how many missing data
df.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
#check if any row completely duplicate
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#now to check ratio of is_duplicate column, how many 1 and how many 0
print(df["is_duplicate"].value_counts())
print((df["is_duplicate"].value_counts()/df["is_duplicate"].count())*100)
df["is_duplicate"].value_counts().plot(kind="bar")
# Out:
# is_duplicate
# 0    255027
# 1    149263
# Name: count, dtype: int64
# is_duplicate
# 0    63.080215
# 1    36.919785
# Name: count, dtype: float64
# <Axes: xlabel='is_duplicate'>
